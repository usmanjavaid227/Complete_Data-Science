# %%
import seaborn as sns
import matplotlib.pyplot as plt

phool=sns.load_dataset("iris")
sns.barplot(x="species",y="sepal_width",data=phool)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

phool=sns.load_dataset("iris")
sns.barplot(x="species",y="petal_length",data=phool)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")
sns.barplot(x="who",y="alone",hue="sex",data=kashti)
plt.show()

# %% [markdown]
# ### set order

# %%
import seaborn as sns
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")
sns.barplot(x="sex",y="alone",hue="who",data=kashti , order=["female" , "male"])
plt.show()

# %% [markdown]
# ### set color

# %%
import seaborn as sns
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")
sns.barplot(x="sex",y="alone",hue="who",data=kashti , order=["female" , "male"], color="green")
plt.show()

# %% [markdown]
# ### confidence interval remove

# %%
import seaborn as sns
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")
sns.barplot(x="sex",y="alone",hue="who",data=kashti , order=["female" , "male"],color="red",ci=None)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

kashti=sns.load_dataset("titanic")
sns.barplot(x="sex",y="alone",hue="who",data=kashti , order=["female" , "male"],color="green",ci=None,
palette="pastel")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy

kashti=sns.load_dataset("titanic")
sns.barplot(x="sex",y="fare",hue="who",data=kashti ,color="green",estimator=median,
palette="pastel")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\OneDrive\Desktop\python\visual\02_bar_plot.ipynb Cell 11' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/python/visual/02_bar_plot.ipynb#ch0000010?line=2'>3</a> import numpy
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/python/visual/02_bar_plot.ipynb#ch0000010?line=4'>5</a> kashti=sns.load_dataset("titanic")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/python/visual/02_bar_plot.ipynb#ch0000010?line=5'>6</a> sns.barplot(x="sex",y="fare",hue="who",data=kashti ,color="green",estimator=median,
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/python/visual/02_bar_plot.ipynb#ch0000010?line=6'>7</a> palette="pastel")
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy

kashti=sns.load_dataset("titanic")
sns.barplot(x="sex",y="fare",hue="who",data=kashti ,color="green",estimator=median,
palette="pastel",saturation=0.5)
plt.show()

# %%
# Horizental plot
import seaborn as sns
import matplotlib.pyplot as plt
import numpy

kashti=sns.load_dataset("titanic")
sns.barplot(x="fare",y="sex",hue="who",data=kashti ,color="green",saturation=1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy

kashti=sns.load_dataset("titanic")
sns.barplot(x="sex",y="fare",hue="who",data=kashti ,color="red",
linewidth=1,errwidth=1,edgecolor="0",facecolor=(0.5,0.5,0.2,1))
plt.show()
