# %% [markdown]
# # _**stepPlot**_

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[3,2,1,2,4]

# %%
plt.step(x,y)
plt.show()

# %%
plt.step(x,y,marker="o",color="r",ms=10,mfc='g')
plt.grid()
plt.show()
