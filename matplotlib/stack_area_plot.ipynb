# %% [markdown]
# # _**stock/Area Plot**_

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
area3=[2,1,4,4,3]
area1=[3,1,5,5,4] 
area2=[4,2,2,3,1]

# %%
plt.stackplot(x,area3,area1,area2)
plt.show()

# %%
plt.stackplot(x,area1,area2,area3,baseline ="sym")
plt.show()
